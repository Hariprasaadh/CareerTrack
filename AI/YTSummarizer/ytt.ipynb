# %%
import os
from dotenv import load_dotenv
from youtube_transcript_api import YouTubeTranscriptApi
from googleapiclient.discovery import build
from langchain_groq import ChatGroq
from langchain.prompts import PromptTemplate

# %%
load_dotenv()
# Out:
# True

# %%
llm = ChatGroq(
    model_name="llama-3.1-70b-versatile",
    temperature=0.4,
    api_key=os.getenv("GROQCLOUD_API")
)

# %%
video_url = "https://www.youtube.com/watch?v=I2ZK3ngNvvI"
video_id = video_url.split("v=")[1].split("&")[0]
transcript_text = YouTubeTranscriptApi.get_transcript(video_id)

# %%
transcript_text
# Out:
# [{'text': "you're one of the greatest teachers of",
#   'start': 2.76,
#   'duration': 7.08},
#  {'text': 'machine learning AI ever from cs231n to',
#   'start': 4.92,
#   'duration': 7.44},
#  {'text': 'today what advice would you give to',
#   'start': 9.84,
#   'duration': 4.02},
#  {'text': 'beginners interested in getting into',
#   'start': 12.36,
#   'duration': 3.06},
#  {'text': 'machine learning', 'start': 13.86, 'duration': 5.28},
#  {'text': 'beginners are often focused on like what',
#   'start': 15.42,
#   'duration': 5.16},
#  {'text': 'to do and I think the focus should be',
#   'start': 19.14,
#   'duration': 4.139},
#  {'text': "more like how much you do so I I'm kind",
#   'start': 20.58,
#   'duration': 4.32},
#  {'text': 'of like believer on a high level in this',
#   'start': 23.279,
#   'duration': 3.901},
#  {'text': '10 000 hours kind of concept where',
#   'start': 24.9,
#   'duration': 3.719},
#  {'text': 'you just kind of have to just pick the',
#   'start': 27.18,
#   'duration': 2.82},
#  {'text': 'things where you can spend time and you',
#   'start': 28.619,
#   'duration': 2.641},
#  {'text': "you care about and you're interested in",
#   'start': 30.0,
#   'duration': 2.7},
#  {'text': 'you literally have to put in 10 000',
#   'start': 31.26,
#   'duration': 2.7},
#  {'text': 'hours of work', 'start': 32.7, 'duration': 2.76},
#  {'text': "um it doesn't even like matter as much",
#   'start': 33.96,
#   'duration': 3.54},
#  {'text': "like where you put it and you'll iterate",
#   'start': 35.46,
#   'duration': 3.779},
#  {'text': "and you'll improve and you'll waste some",
#   'start': 37.5,
#   'duration': 3.0},
#  {'text': "time I don't know if there's a better",
#   'start': 39.239,
#   'duration': 3.601},
#  {'text': 'way you need to put in 10 000 hours but',
#   'start': 40.5,
#   'duration': 3.18},
#  {'text': "I think it's actually really nice",
#   'start': 42.84,
#   'duration': 1.86},
#  {'text': "because I feel like there's some sense",
#   'start': 43.68,
#   'duration': 3.78},
#  {'text': 'of determinism about being an expert at',
#   'start': 44.7,
#   'duration': 4.08},
#  {'text': 'a thing if you spend ten thousand hours',
#   'start': 47.46,
#   'duration': 3.599},
#  {'text': 'you can literally pick an arbitrary',
#   'start': 48.78,
#   'duration': 4.02},
#  {'text': 'thing and I think if you spend ten',
#   'start': 51.059,
#   'duration': 3.361},
#  {'text': 'thousand hours of deliberate effort and',
#   'start': 52.8,
#   'duration': 3.12},
#  {'text': 'work you actually will become an expert',
#   'start': 54.42,
#   'duration': 4.139},
#  {'text': "at it and so I think it's kind of like a",
#   'start': 55.92,
#   'duration': 4.26},
#  {'text': 'nice thought', 'start': 58.559, 'duration': 4.32},
#  {'text': 'um and so uh basically I would focus',
#   'start': 60.18,
#   'duration': 4.26},
#  {'text': 'more on like are you spending ten',
#   'start': 62.879,
#   'duration': 3.361},
#  {'text': "thousand hours that's what I'm focus on",
#   'start': 64.44,
#   'duration': 3.719},
#  {'text': 'so and then thinking about what kind of',
#   'start': 66.24,
#   'duration': 4.379},
#  {'text': 'mechanisms maximize your likelihood of',
#   'start': 68.159,
#   'duration': 4.021},
#  {'text': 'getting to ten thousand dollars exactly',
#   'start': 70.619,
#   'duration': 4.741},
#  {'text': 'which for us silly humans means probably',
#   'start': 72.18,
#   'duration': 5.64},
#  {'text': 'forming a daily habit of like every',
#   'start': 75.36,
#   'duration': 3.84},
#  {'text': 'single day actually doing the thing',
#   'start': 77.82,
#   'duration': 3.24},
#  {'text': 'whatever helps you so I do think to a',
#   'start': 79.2,
#   'duration': 3.12},
#  {'text': 'large extent is a psychological problem',
#   'start': 81.06,
#   'duration': 3.599},
#  {'text': 'for yourself uh one other thing that I',
#   'start': 82.32,
#   'duration': 4.02},
#  {'text': 'hope that I think is helpful for the',
#   'start': 84.659,
#   'duration': 3.361},
#  {'text': 'psychology of it is many times people',
#   'start': 86.34,
#   'duration': 3.36},
#  {'text': 'compare themselves to others in the area',
#   'start': 88.02,
#   'duration': 3.54},
#  {'text': 'I think this is very harmful only',
#   'start': 89.7,
#   'duration': 3.66},
#  {'text': 'compare yourself to you from some time',
#   'start': 91.56,
#   'duration': 4.199},
#  {'text': 'ago like say a year ago are you better',
#   'start': 93.36,
#   'duration': 4.38},
#  {'text': 'than you year ago this is the only way',
#   'start': 95.759,
#   'duration': 3.241},
#  {'text': 'to think', 'start': 97.74, 'duration': 3.0},
#  {'text': 'um and I think this then you can see',
#   'start': 99.0,
#   'duration': 3.18},
#  {'text': "your progress and it's very motivating",
#   'start': 100.74,
#   'duration': 4.199},
#  {'text': "that's so interesting that focus on the",
#   'start': 102.18,
#   'duration': 5.04},
#  {'text': 'quantity of ours because I think a lot',
#   'start': 104.939,
#   'duration': 4.441},
#  {'text': 'of people uh in the beginner stage but',
#   'start': 107.22,
#   'duration': 4.859},
#  {'text': 'actually throughout get paralyzed',
#   'start': 109.38,
#   'duration': 6.84},
#  {'text': 'uh by uh the choice like which one do I',
#   'start': 112.079,
#   'duration': 6.601},
#  {'text': 'pick this path or this path yeah like',
#   'start': 116.22,
#   'duration': 4.38},
#  {'text': "they'll literally get paralyzed by like",
#   'start': 118.68,
#   'duration': 3.719},
#  {'text': "which ID to use well they're worried",
#   'start': 120.6,
#   'duration': 3.059},
#  {'text': "yeah they're worried about all these",
#   'start': 122.399,
#   'duration': 3.241},
#  {'text': 'things but the thing is some of the you',
#   'start': 123.659,
#   'duration': 3.361},
#  {'text': 'you will waste time doing something',
#   'start': 125.64,
#   'duration': 2.819},
#  {'text': 'wrong yes you will eventually figure out',
#   'start': 127.02,
#   'duration': 2.879},
#  {'text': "it's not right you will accumulate scar",
#   'start': 128.459,
#   'duration': 3.661},
#  {'text': "tissue and next time you'll grow",
#   'start': 129.899,
#   'duration': 3.541},
#  {'text': "stronger because next time you'll have",
#   'start': 132.12,
#   'duration': 3.119},
#  {'text': "the scar tissue and next time you'll",
#   'start': 133.44,
#   'duration': 3.78},
#  {'text': 'learn from it and now next time you come',
#   'start': 135.239,
#   'duration': 3.36},
#  {'text': "into a similar situation you'll be like",
#   'start': 137.22,
#   'duration': 2.46},
#  {'text': 'all right', 'start': 138.599, 'duration': 3.421},
#  {'text': "I messed up I've spent a lot of time",
#   'start': 139.68,
#   'duration': 3.84},
#  {'text': 'working on things that never materialize',
#   'start': 142.02,
#   'duration': 3.18},
#  {'text': 'into anything and I have all that scar',
#   'start': 143.52,
#   'duration': 3.06},
#  {'text': 'tissue and I have some intuitions about',
#   'start': 145.2,
#   'duration': 3.3},
#  {'text': "what was useful what wasn't useful how",
#   'start': 146.58,
#   'duration': 3.9},
#  {'text': 'things turned out so all those mistakes',
#   'start': 148.5,
#   'duration': 4.98},
#  {'text': 'were uh were not dead work you know so I',
#   'start': 150.48,
#   'duration': 4.38},
#  {'text': 'just think you should just focus on',
#   'start': 153.48,
#   'duration': 3.6},
#  {'text': 'working what have you done what have you',
#   'start': 154.86,
#   'duration': 4.019},
#  {'text': 'done last week', 'start': 157.08, 'duration': 3.96},
#  {'text': "uh that's a good question actually to",
#   'start': 158.879,
#   'duration': 4.201},
#  {'text': 'ask for for a lot of things not just',
#   'start': 161.04,
#   'duration': 3.66},
#  {'text': 'machine learning', 'start': 163.08, 'duration': 4.019},
#  {'text': "um it's a good way to cut the", 'start': 164.7, 'duration': 4.2},
#  {'text': 'the I forgot what the term will use but',
#   'start': 167.099,
#   'duration': 4.86},
#  {'text': 'the fluff the blubber whatever the uh',
#   'start': 168.9,
#   'duration': 5.58},
#  {'text': 'the inefficiencies in life uh what do',
#   'start': 171.959,
#   'duration': 5.461},
#  {'text': 'you love about teaching you seem to find',
#   'start': 174.48,
#   'duration': 4.08},
#  {'text': 'yourself', 'start': 177.42, 'duration': 3.24},
#  {'text': 'often in the like drawn to teaching',
#   'start': 178.56,
#   'duration': 3.539},
#  {'text': "you're very good at it but you're also",
#   'start': 180.66,
#   'duration': 3.0},
#  {'text': "drawn to it I mean I don't think I love",
#   'start': 182.099,
#   'duration': 4.741},
#  {'text': 'teaching I love happy humans', 'start': 183.66, 'duration': 6.6},
#  {'text': 'and happy humans like when I teach yes I',
#   'start': 186.84,
#   'duration': 4.8},
#  {'text': "I wouldn't say I hate teaching I",
#   'start': 190.26,
#   'duration': 2.82},
#  {'text': "tolerate teaching but it's not like the",
#   'start': 191.64,
#   'duration': 3.179},
#  {'text': "act of teaching that I like it's it's",
#   'start': 193.08,
#   'duration': 4.92},
#  {'text': 'that um you know I I have some I have',
#   'start': 194.819,
#   'duration': 5.461},
#  {'text': "something I'm actually okay at it yes",
#   'start': 198.0,
#   'duration': 3.48},
#  {'text': "I'm okay at teaching and people",
#   'start': 200.28,
#   'duration': 4.14},
#  {'text': "appreciate it a lot yeah and uh so I'm",
#   'start': 201.48,
#   'duration': 5.399},
#  {'text': 'just happy to try to be helpful and uh',
#   'start': 204.42,
#   'duration': 4.8},
#  {'text': 'teaching itself is not like the most I',
#   'start': 206.879,
#   'duration': 3.661},
#  {'text': "mean it's really no it can be really",
#   'start': 209.22,
#   'duration': 3.18},
#  {'text': 'annoying frustrating I was working on a',
#   'start': 210.54,
#   'duration': 3.419},
#  {'text': 'bunch of lectures just now I was', 'start': 212.4, 'duration': 3.9},
#  {'text': 'reminded back to my days of 231 and just',
#   'start': 213.959,
#   'duration': 4.081},
#  {'text': 'how much work it is to create some of',
#   'start': 216.3,
#   'duration': 3.299},
#  {'text': 'these materials and make them good the',
#   'start': 218.04,
#   'duration': 3.119},
#  {'text': 'amount of iteration and thought and you',
#   'start': 219.599,
#   'duration': 3.36},
#  {'text': 'go down blind alleys and just how much',
#   'start': 221.159,
#   'duration': 4.86},
#  {'text': 'you change it so creating something good',
#   'start': 222.959,
#   'duration': 4.92},
#  {'text': 'um in terms of like educational value is',
#   'start': 226.019,
#   'duration': 5.161},
#  {'text': "really hard and uh it's not fun it's",
#   'start': 227.879,
#   'duration': 4.86},
#  {'text': 'difficult so for people should', 'start': 231.18, 'duration': 3.36},
#  {'text': 'definitely go watch your new stuff you',
#   'start': 232.739,
#   'duration': 3.901},
#  {'text': "put out there are lectures where you're",
#   'start': 234.54,
#   'duration': 3.479},
#  {'text': 'actually building the thing like from',
#   'start': 236.64,
#   'duration': 3.54},
#  {'text': 'like you said the code is truth so',
#   'start': 238.019,
#   'duration': 4.681},
#  {'text': 'discussing uh back propagation by',
#   'start': 240.18,
#   'duration': 4.559},
#  {'text': 'building it by looking through and just',
#   'start': 242.7,
#   'duration': 3.539},
#  {'text': 'the whole thing so how difficult is that',
#   'start': 244.739,
#   'duration': 3.06},
#  {'text': "to prepare for I think that's a really",
#   'start': 246.239,
#   'duration': 3.78},
#  {'text': 'powerful way to teach how did you have',
#   'start': 247.799,
#   'duration': 4.321},
#  {'text': 'to prepare for that or are you just live',
#   'start': 250.019,
#   'duration': 4.561},
#  {'text': 'thinking through it I will typically do',
#   'start': 252.12,
#   'duration': 4.079},
#  {'text': 'like say three takes and then I take',
#   'start': 254.58,
#   'duration': 3.899},
#  {'text': 'like the the better take uh so I do',
#   'start': 256.199,
#   'duration': 3.481},
#  {'text': 'multiple takes and I take some of the',
#   'start': 258.479,
#   'duration': 2.341},
#  {'text': 'better takes and then I just build out a',
#   'start': 259.68,
#   'duration': 3.239},
#  {'text': 'lecture that way uh sometimes I have to',
#   'start': 260.82,
#   'duration': 4.08},
#  {'text': 'delete 30 minutes of content because it',
#   'start': 262.919,
#   'duration': 3.181},
#  {'text': "just went down in alley that I didn't",
#   'start': 264.9,
#   'duration': 3.0},
#  {'text': "like too much there's about a bunch of",
#   'start': 266.1,
#   'duration': 4.44},
#  {'text': 'iteration and it probably takes me you',
#   'start': 267.9,
#   'duration': 3.9},
#  {'text': 'know somewhere around 10 hours to create',
#   'start': 270.54,
#   'duration': 2.939},
#  {'text': 'one hour of content to give one hour',
#   'start': 271.8,
#   'duration': 4.2},
#  {'text': "it's interesting I mean is it difficult",
#   'start': 273.479,
#   'duration': 4.981},
#  {'text': 'to go back to the like the basics do you',
#   'start': 276.0,
#   'duration': 4.68},
#  {'text': 'draw a lot of like wisdom from going',
#   'start': 278.46,
#   'duration': 3.84},
#  {'text': 'back to the basics yeah going back to',
#   'start': 280.68,
#   'duration': 3.0},
#  {'text': 'back propagation loss functions where',
#   'start': 282.3,
#   'duration': 2.7},
#  {'text': 'they come from and one thing I like',
#   'start': 283.68,
#   'duration': 3.42},
#  {'text': 'about teaching a lot honestly is it',
#   'start': 285.0,
#   'duration': 3.06},
#  {'text': 'definitely strengthens your', 'start': 287.1, 'duration': 3.659},
#  {'text': "understanding uh so it's not a purely",
#   'start': 288.06,
#   'duration': 4.44},
#  {'text': "altruistic activity it's a way to learn",
#   'start': 290.759,
#   'duration': 3.841},
#  {'text': 'if you have to explain something to',
#   'start': 292.5,
#   'duration': 4.68},
#  {'text': 'someone uh you realize you have gaps in',
#   'start': 294.6,
#   'duration': 5.879},
#  {'text': 'knowledge uh and so I even surprised',
#   'start': 297.18,
#   'duration': 5.28},
#  {'text': 'myself in those lectures like also the',
#   'start': 300.479,
#   'duration': 3.421},
#  {'text': 'result will obviously look at this and',
#   'start': 302.46,
#   'duration': 2.64},
#  {'text': "then the result doesn't look like it and",
#   'start': 303.9,
#   'duration': 3.0},
#  {'text': "I'm like okay I thought I understood",
#   'start': 305.1,
#   'duration': 3.14},
#  {'text': 'yeah', 'start': 306.9, 'duration': 3.44},
#  {'text': "but that's why it's really cool to",
#   'start': 308.24,
#   'duration': 4.84},
#  {'text': 'literally code you run it in a notebook',
#   'start': 310.34,
#   'duration': 4.24},
#  {'text': "and it gives you a result and you're",
#   'start': 313.08,
#   'duration': 3.78},
#  {'text': 'like oh wow yes and like actual numbers',
#   'start': 314.58,
#   'duration': 4.5},
#  {'text': 'actual input X you know actual code yeah',
#   'start': 316.86,
#   'duration': 3.96},
#  {'text': "it's not mathematical symbols Etc the",
#   'start': 319.08,
#   'duration': 3.42},
#  {'text': "source of Truth is the code it's not",
#   'start': 320.82,
#   'duration': 4.02},
#  {'text': "slides it's just like let's build it",
#   'start': 322.5,
#   'duration': 4.38},
#  {'text': "it's beautiful you're a rare human in",
#   'start': 324.84,
#   'duration': 4.4},
#  {'text': 'that sense', 'start': 326.88, 'duration': 2.36}]

# %%
transcript = " ".join([i["text"] for i in transcript_text])

# %%
transcript
# Out:
# "you're one of the greatest teachers of machine learning AI ever from cs231n to today what advice would you give to beginners interested in getting into machine learning beginners are often focused on like what to do and I think the focus should be more like how much you do so I I'm kind of like believer on a high level in this 10 000 hours kind of concept where you just kind of have to just pick the things where you can spend time and you you care about and you're interested in you literally have to put in 10 000 hours of work um it doesn't even like matter as much like where you put it and you'll iterate and you'll improve and you'll waste some time I don't know if there's a better way you need to put in 10 000 hours but I think it's actually really nice because I feel like there's some sense of determinism about being an expert at a thing if you spend ten thousand hours you can literally pick an arbitrary thing and I think if you spend ten thousand hours of deliberate effort and work you actually will become an expert at it and so I think it's kind of like a nice thought um and so uh basically I would focus more on like are you spending ten thousand hours that's what I'm focus on so and then thinking about what kind of mechanisms maximize your likelihood of getting to ten thousand dollars exactly which for us silly humans means probably forming a daily habit of like every single day actually doing the thing whatever helps you so I do think to a large extent is a psychological problem for yourself uh one other thing that I hope that I think is helpful for the psychology of it is many times people compare themselves to others in the area I think this is very harmful only compare yourself to you from some time ago like say a year ago are you better than you year ago this is the only way to think um and I think this then you can see your progress and it's very motivating that's so interesting that focus on the quantity of ours because I think a lot of people uh in the beginner stage but actually throughout get paralyzed uh by uh the choice like which one do I pick this path or this path yeah like they'll literally get paralyzed by like which ID to use well they're worried yeah they're worried about all these things but the thing is some of the you you will waste time doing something wrong yes you will eventually figure out it's not right you will accumulate scar tissue and next time you'll grow stronger because next time you'll have the scar tissue and next time you'll learn from it and now next time you come into a similar situation you'll be like all right I messed up I've spent a lot of time working on things that never materialize into anything and I have all that scar tissue and I have some intuitions about what was useful what wasn't useful how things turned out so all those mistakes were uh were not dead work you know so I just think you should just focus on working what have you done what have you done last week uh that's a good question actually to ask for for a lot of things not just machine learning um it's a good way to cut the the I forgot what the term will use but the fluff the blubber whatever the uh the inefficiencies in life uh what do you love about teaching you seem to find yourself often in the like drawn to teaching you're very good at it but you're also drawn to it I mean I don't think I love teaching I love happy humans and happy humans like when I teach yes I I wouldn't say I hate teaching I tolerate teaching but it's not like the act of teaching that I like it's it's that um you know I I have some I have something I'm actually okay at it yes I'm okay at teaching and people appreciate it a lot yeah and uh so I'm just happy to try to be helpful and uh teaching itself is not like the most I mean it's really no it can be really annoying frustrating I was working on a bunch of lectures just now I was reminded back to my days of 231 and just how much work it is to create some of these materials and make them ...

# %%
prompt = PromptTemplate.from_template(
    """
    INPUT:
    # Transcript: {transcript}

    ### Enhanced YouTube Video Summariser and Analysis for Academic and Career Growth
    - Extract the keywords from the transcript provided and summarise only that. Don't say what speaker is doing.
    - Don't include the word "Speaker"
    - Only summarise the technical contents add some more points to it if needed only for technical concepts.
    - Accurately summarise the spoken content of the given YouTube video, preserving context, technical terms, and key points.
    - Summarize the transcription into concise sections, highlighting critical takeaways.
    
    OUTPUT STRUCTURE:
    #Topic and Subject Domain
    #Technical Concepts
    #Summary
    #Additional Points
    #Key Takeaways
    """
)

# %%
model = prompt | llm
res = model.invoke(input={'transcript': transcript})
print("Video Summary:", res.content)
# Out:
# Video Summary: #Topic and Subject Domain
# Machine Learning, Artificial Intelligence, and Education
#
# #Technical Concepts
# - 10,000 hours concept for expertise development
# - Deliberate practice and effort
# - Daily habits for skill development
# - Comparison with oneself for progress tracking
# - Backpropagation
# - Loss functions
# - Code as the source of truth
# - Iterative learning and improvement
#
# #Summary
# The importance of putting in time and effort to develop expertise in machine learning is emphasized. The 10,000 hours concept is discussed as a means to achieve mastery, regardless of the specific area of focus. It is also highlighted that comparing oneself to others can be detrimental, and instead, one should focus on personal progress and improvement. The value of deliberate practice, daily habits, and learning from mistakes is also stressed. Additionally, the technical aspects of machine learning, such as backpropagation and loss functions, are discussed as fundamental concepts that require a deep understanding.
#
# #Additional Points
# - The process of creating educational content, such as lectures, can be time-consuming and requires significant iteration and refinement.
# - Teaching can be a means to strengthen one's own understanding of a subject and identify knowledge gaps.
# - The use of code and actual implementation can be a powerful tool for learning and understanding complex concepts.
# - The concept of "scar tissue" is introduced, referring to the accumulation of knowledge and experience gained from past mistakes and failures.
#
# #Key Takeaways
# - Developing expertise in machine learning requires a significant amount of time and effort.
# - Focus on personal progress and improvement, rather than comparing oneself to others.
# - Deliberate practice, daily habits, and learning from mistakes are essential for skill development.
# - A deep understanding of fundamental concepts, such as backpropagation and loss functions, is crucial for success in machine learning.
# - The use of code and actual implementation can be a powerful tool for learning and understanding complex concepts.
